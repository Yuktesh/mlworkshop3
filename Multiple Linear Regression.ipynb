# %%
import pandas as pd
import numpy as np

# %%
#read the dataset
data = pd.read_csv("50_startups.csv")

# %%
data.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39

# %%
#check for null values
data.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
#Here we should do label encoding as we have 1 column state as textual data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['State'] = le.fit_transform(data['State'])

# %%
#Check the State column whether it converted into numericals or not
data
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
#split the data into x and y
x=data.iloc[:,0:4].values
y=data.iloc[:,4:5].values

# %%
# check x with splitted rows came or not ( first 4 rows)
x
# Out:
# array([[1.6534920e+05, 1.3689780e+05, 4.7178410e+05, 2.0000000e+00],
#        [1.6259770e+05, 1.5137759e+05, 4.4389853e+05, 0.0000000e+00],
#        [1.5344151e+05, 1.0114555e+05, 4.0793454e+05, 1.0000000e+00],
#        [1.4437241e+05, 1.1867185e+05, 3.8319962e+05, 2.0000000e+00],
#        [1.4210734e+05, 9.1391770e+04, 3.6616842e+05, 1.0000000e+00],
#        [1.3187690e+05, 9.9814710e+04, 3.6286136e+05, 2.0000000e+00],
#        [1.3461546e+05, 1.4719887e+05, 1.2771682e+05, 0.0000000e+00],
#        [1.3029813e+05, 1.4553006e+05, 3.2387668e+05, 1.0000000e+00],
#        [1.2054252e+05, 1.4871895e+05, 3.1161329e+05, 2.0000000e+00],
#        [1.2333488e+05, 1.0867917e+05, 3.0498162e+05, 0.0000000e+00],
#        [1.0191308e+05, 1.1059411e+05, 2.2916095e+05, 1.0000000e+00],
#        [1.0067196e+05, 9.1790610e+04, 2.4974455e+05, 0.0000000e+00],
#        [9.3863750e+04, 1.2732038e+05, 2.4983944e+05, 1.0000000e+00],
#        [9.1992390e+04, 1.3549507e+05, 2.5266493e+05, 0.0000000e+00],
# ...

# %%
#same for y check last column (ie profit) is shoowing or not
y
# Out:
# array([[192261.83],
#        [191792.06],
#        [191050.39],
#        [182901.99],
#        [166187.94],
#        [156991.12],
#        [156122.51],
#        [155752.6 ],
#        [152211.77],
#        [149759.96],
#        [146121.95],
#        [144259.4 ],
#        [141585.52],
#        [134307.35],
#        [132602.65],
#        [129917.04],
#        [126992.93],
#        [125370.37],
#        [124266.9 ],
#        [122776.86],
#        [118474.03],
#        [111313.02],
#        [110352.25],
#        [108733.99],
#        [108552.04],
#        [107404.34],
#        [105733.54],
#        [105008.31],
#        [103282.38],
#        [101004.64],
#        [ 99937.59],
#        [ 97483.56],
#        [ 97427.84],
#        [ 96778.92],
#        [ 96712.8 ],
#        [ 96479.51],
#        [ 90708.19],
#        [ 89949.14],
#        [ 81229.06],
#        [ 81005.76],
#        [ 78239.91],
#        [ 77798.83],
#        [ 71498.49],
#        [ 69758.98],
#        [ 65200.33],
# ...

# %%
#check total how many values are there in State colum
data['State'].max()
#we got 2 means total 3 values are there 0,1,2 it means total 3 categorical values were there is the understanding
# Out:
# 2

# %%
#perform one hot encoding
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()
z = one.fit_transform(x[:,3:4]).toarray()
x = np.delete(x,3,axis = 1)

x = np.concatenate((z,x), axis = 1)

# %%
x.shape
# Out:
# (50, 54)

# %% [raw]
# newyork is 2
# California is 0
# Florida is 1
# California     Florida     Newyork   RandD. Admin   MrktSpnd
#       0.          0.         1

# %%
#split the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 0)

# %%
#train your model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#test your model
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[198994.31174266],
#        [ 59244.67076035],
#        [ 85489.14518463],
#        [ 37377.01565787],
#        [ 82126.79213822],
#        [136233.13423267],
#        [ 20217.98290215],
#        [159453.94707577],
#        [111211.37369771],
#        [ 62776.32558301]])

# %%
#check for accuracy
from sklearn.metrics import r2_score
accuracy = r2_score(y_test,y_pred)

# %%
accuracy
# Out:
# -3.128204357685193

# %%
#Now lets test individual values
y = regressor.predict([[0,0,1,12345,12345,12345]])
y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-165a496f7a1a> in <module>
#       1 #Now lets test individual values
# ----> 2 y = regressor.predict([[0,0,1,12345,12345,12345]])
#       3 y
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
#     211     def predict(self, X):
#
# ...

# %% [markdown]
# R&D Spend, Administration,MarketSpend as 12345 each then the profit is going to be 53659.9002904
